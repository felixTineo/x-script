# %% [markdown]
# ## Import files

# %%
import requests
from dotenv import load_dotenv
import os
from newsdataapi import NewsDataApiClient
import json

# %% [markdown]
# ### CONFIG

# %%
load_dotenv()
news_api_url = os.getenv('NEWS_API_URL')
news_api_version = os.getenv('NEWS_API_VERSION')
news_api_key = os.getenv('NEWS_API_KEY')
url = f'{news_api_url}/{news_api_version}/latest'

# %%
api = NewsDataApiClient(apikey=news_api_key)
response = api.news_api(category="politics", country="ve")
print(json.dumps(
    response, 
    indent=4, 
    sort_keys=True
))
# Out:
# /tmp/ipykernel_620809/3440964130.py:2: DeprecationWarning: This method is deprecated and will be removed in upcoming updates, Instead use latest_api()
#   response = api.news_api(category="politics", country="ve")
# {
#     "nextPage": "1736893584132611125",
#     "results": [
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "5c9d7b104a5c1a76b84d10169265dcfd",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "TalCual"
#             ],
#             "description": null,
#             "duplicate": false,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/JORGER_Elecciones.jpg",
#             "keywords": [
#                 "rodr\u00edguez",
#                 "cne",
#                 "2025",
#                 "elecciones",
#                 "pa\u00eds pol\u00edtico"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/jorge-rodriguez-es-muy-probable-que-debamos-realizar-elecciones-muy-pronto/",
#             "pubDate": "2025-01-15 02:18:00",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Jorge Rodri\u0301guez: \u201cEs muy probable que debamos realizar elecciones muy pronto\u201d",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "d01de2e17abe405b1d0327e9e0eb712f",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "Efecto Cocuyo"
#             ],
#             "description": "El polito\u0301logo Piero Trepiccione sen\u0303ala que actual Carta Magna es una \"camisa de fuerza\" para li\u0301der del PsuvThe post Que\u0301 busca Maduro con una reforma constitucional appeared first on Efecto Cocuyo.",
#             "duplicate": false,
#             "image_url": "https://i0.wp.com/efectococuyo.com/wp-content/uploads/2025/01/4915799549168168820.jpg?fit=1024%2C576&ssl=1",
#             "keywords": [
#                 "reforma constitucional",
#                 "nicol\u00e1s maduro",
#                 "maria corina machado",
#                 "chavismo disidente",
#                 "pol\u00edtica",
#                 "psuv"
#             ],
#             "language": "spanish",
#             "link": "https://efectococuyo.com/politica/aumentar-poder-frente-voto-popular-adverso-lo-que-busca-maduro-con-reforma-constitucional/",
#             "pubDate": "2025-01-15 01:24:21",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/efectococuyo.png",
#             "source_id": "efectococuyo",
#             "source_name": "Efectococuyo",
#             "source_priority": 139066,
#             "source_url": "https://efectococuyo.com",
#             "title": "Que\u0301 busca Maduro con una reforma constitucional",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "16ebe8ade66c66e258dc363d21242396",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "Runrun.es"
#             ],
#             "description": null,
#             "duplicate": false,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/VIOLENCIA_estatal.jpg",
#             "keywords": [
#                 "a - modulo 7 - b",
#                 "femicidios",
#                 "crisis",
#                 "pa\u00eds pol\u00edtico",
#                 "estado",
#                 "foro penal",
#                 "cne",
#                 "violencia",
#                 "maduro"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/violencia-estatal-y-femicidios-enlutaron-familias-venezolanas-en-2024/",
#             "pubDate": "2025-01-15 01:21:21",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Violencia estatal y femicidios enlutaron familias venezolanas en 2024",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "d6424d79033e081e76aabb6b6907410f",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "Efecto Cocuyo | @efectococuyo"
#             ],
#             "description": "Los expertos analizaron el costo de la ilegitimidad del gobierno de Maduro, la necesidad de una resistencia paci\u0301fica ante el autoritarismoThe post \u00bfDespue\u0301s del 10-E, cua\u0301l es la ruta? Sergio Sa\u0301nchez, Mariana Aylwin y Jesu\u0301s Castellanos responden #ConLaLuz appeared first on Efecto Cocuyo.",
#             "duplicate": false,
#             "image_url": "https://i0.wp.com/efectococuyo.com/wp-content/uploads/2025/01/WhatsApp-Image-2025-01-15-at-01.07.21.jpeg?fit=1024%2C683&ssl=1",
#             "keywords": [
#                 "nicol\u00e1s maduro",
#                 "edmundo gonz\u00e1lez urrutia",
#                 "mar\u00eda corina machado",
#                 "pol\u00edtica",
#                 "juramentaci\u00f3n 2025",
#                 "con la luz"
#             ],
#             "language": "spanish",
#             "link": "https://efectococuyo.com/politica/con-la-luz-patricia-aylwin-jesus-castellanos-sergio-sanchez-15-enero/",
#             "pubDate": "2025-01-15 00:35:47",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/efectococuyo.png",
#             "source_id": "efectococuyo",
#             "source_name": "Efectococuyo",
#             "source_priority": 139066,
#             "source_url": "https://efectococuyo.com",
#             "title": "\u00bfDespue\u0301s del 10-E, cua\u0301l es la ruta? Sergio Sa\u0301nchez, Mariana Aylwin y Jesu\u0301s Castellanos responden #ConLaLuz",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "f7dd374d9e0d093460a51c8aac25708c",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "El Carabobe\u00f1o"
#             ],
#             "description": null,
#             "duplicate": false,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/EXPERTOS_ONU.jpg",
#             "keywords": [
#                 "desapariciones",
#                 "elecciones",
#                 "onu",
#                 "venezuela",
#                 "a - modulo 7 - a",
#                 "pa\u00eds pol\u00edtico",
#                 "expertos",
#                 "detenidos",
#                 "condiciones"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/expertos-de-la-onu-exponen-condiciones-inadecuadas-de-detencion-en-venezuela/",
#             "pubDate": "2025-01-15 00:19:42",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Expertos de la ONU exponen condiciones inadecuadas de detencio\u0301n en Venezuela",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "5fd144705269fc43557bdb92b02ee57a",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "La Verdad"
#             ],
#             "description": null,
#             "duplicate": false,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/CANCILLERIA_Ccs.jpg",
#             "keywords": [
#                 "canciller\u00eda",
#                 "tres",
#                 "pa\u00edses bajos",
#                 "representaci\u00f3n",
#                 "a - modulo 7 - a",
#                 "italia",
#                 "pa\u00eds pol\u00edtico",
#                 "francia",
#                 "diplom\u00e1ticos"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/cancilleria-reducira-representacion-diplomatica-de-paises-bajos-francia-e-italia/",
#             "pubDate": "2025-01-14 23:47:25",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Cancilleri\u0301a reducira\u0301 representacio\u0301n diploma\u0301tica de Pai\u0301ses Bajos, Francia e Italia",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "575775a91c2419296255c0c2ba262c10",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "El Nacional"
#             ],
#             "description": null,
#             "duplicate": true,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/PB_Maduro.jpg",
#             "keywords": [
#                 "di\u00e1logo",
#                 "veldkamp",
#                 "venezuela",
#                 "maduro",
#                 "pa\u00edses bajos",
#                 "elecciones",
#                 "a - modulo 7 - a",
#                 "pa\u00eds pol\u00edtico"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/paises-bajos-acusa-a-maduro-de-escalada-al-limitar-a-3-el-numero-de-diplomaticos-en-venezuela/",
#             "pubDate": "2025-01-14 23:31:56",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Pai\u0301ses Bajos acusa a Maduro de escalada al limitar a 3 el nu\u0301mero de diploma\u0301ticos en Venezuela",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "084aec2c1fa4f441637f772da29140ba",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "TalCual"
#             ],
#             "description": null,
#             "duplicate": false,
#             "image_url": "https://correodelcaroni.com/wp-content/uploads/2025/01/EDMUNDOG_Guatemala.jpg",
#             "keywords": [
#                 "ar\u00e9valo",
#                 "guatemala",
#                 "gira",
#                 "edmundo",
#                 "democracia",
#                 "rep\u00fablica dominicana",
#                 "pa\u00eds pol\u00edtico",
#                 "a - carrusel 1"
#             ],
#             "language": "spanish",
#             "link": "https://correodelcaroni.com/pais-politico/gonzalez-urrutia-arriba-a-guatemala-procedente-de-republica-dominicana/",
#             "pubDate": "2025-01-14 23:16:00",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/correodelcaroni.jpg",
#             "source_id": "correodelcaroni",
#             "source_name": "Correo Del Caron\u00ed",
#             "source_priority": 1981075,
#             "source_url": "https://correodelcaroni.com",
#             "title": "Gonza\u0301lez Urrutia arriba a Guatemala procedente de Repu\u0301blica Dominicana",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "38e0b5e5761ed3601db494809cdb3969",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "Efecto Cocuyo | @efectococuyo"
#             ],
#             "description": "Sera\u0301 recibido este mie\u0301rcoles por el presidente Carlos Ramiro Marti\u0301nezThe post Gonza\u0301lez Urrutia llega a Guatemala para seguir su gira appeared first on Efecto Cocuyo.",
#             "duplicate": false,
#             "image_url": "https://i0.wp.com/efectococuyo.com/wp-content/uploads/2025/01/c58414e6f9e8216a921e1af80b9b476837d074b2.jpg?fit=1024%2C683&ssl=1",
#             "keywords": [
#                 "pol\u00edtica"
#             ],
#             "language": "spanish",
#             "link": "https://efectococuyo.com/politica/gonzalez-urrutia-llega-a-guatemala-para-seguir-su-gira/",
#             "pubDate": "2025-01-14 22:33:49",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/efectococuyo.png",
#             "source_id": "efectococuyo",
#             "source_name": "Efectococuyo",
#             "source_priority": 139066,
#             "source_url": "https://efectococuyo.com",
#             "title": "Gonza\u0301lez Urrutia llega a Guatemala para seguir su gira",
#             "video_url": null
#         },
#         {
#             "ai_org": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_region": "ONLY AVAILABLE IN CORPORATE PLANS",
#             "ai_tag": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "article_id": "9c780f882726cb39817072bb94a087dc",
#             "category": [
#                 "politics"
#             ],
#             "content": "ONLY AVAILABLE IN PAID PLANS",
#             "country": [
#                 "venezuela"
#             ],
#             "creator": [
#                 "\u00daltimas Noticias"
#             ],
#             "description": "\"Condenamos todos los intentos fascistas y neofascistas, externos e internos, representados\" por el Gobierno de Estados Unidos, dijeronLa entrada Partido de Unidad Democra\u0301tico de Jordania expresa respaldo a Maduro se publico\u0301 primero en U\u0301ltimas Noticias.",
#             "duplicate": false,
#             "image_url": "https://ultimasnoticias.com.ve/wp-content/uploads/2025/01/Captura-de-pantalla_14-1-2025_164258_mppre.gob_.ve_.jpeg",
#             "keywords": [
#                 "respaldo",
#                 "zxgeneral",
#                 "partido de unidad democr\u00e1tico",
#                 "maduro",
#                 "pol\u00edtica",
#                 "jordania"
#             ],
#             "language": "spanish",
#             "link": "https://ultimasnoticias.com.ve/noticias/politica/partido-de-unidad-democratico-de-jordania-expresa-respaldo-a-maduro/",
#             "pubDate": "2025-01-14 22:26:24",
#             "pubDateTZ": "UTC",
#             "sentiment": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "sentiment_stats": "ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS",
#             "source_icon": "https://i.bytvi.com/domain_icons/ultimasnoticias.png",
#             "source_id": "ultimasnoticias",
#             "source_name": "Ultimasnoticias",
#             "source_priority": 307579,
#             "source_url": "https://ultimasnoticias.com.ve",
#             "title": "Partido de Unidad Democra\u0301tico de Jordania expresa respaldo a Maduro",
#             "video_url": null
#         }
#     ],
#     "status": "success",
#     "totalResults": 69
# }
